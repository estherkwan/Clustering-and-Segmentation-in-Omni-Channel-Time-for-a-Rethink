# %%
#import behavioural data set with merged k means cluster results from stpe 2
import pandas as pd
import numpy as np
df = pd.read_excel('final_behavioural_k.xlsx')

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
#1.Separate the target variable (Y) from the predictors (X)s
#2.Split data (test/train)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(df.loc[:, df.columns != 'cluster'], df['cluster'], 
		test_size = 0.2, random_state=5) 

# print the shapes to check everything is OK
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (7332, 12)
# (1833, 12)
# (7332,)
# (1833,)

# %%
#3.Fit model, Run on Training Data

from sklearn.neighbors import KNeighborsClassifier as KNN
knn = KNN()

# fit the model using some training data, learn the rules 
knn.fit = knn.fit(X_train[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']], Y_train)

# generate a mean accuracy score for the predicted data
train_score = knn.score(X_train[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']], Y_train)

# print the mean accuracy of testing predictions
print("Accuracy score = " + str(round(train_score, 4)))
# Out:
# Accuracy score = 0.476

# %%
#4.confusion matrix; Check the accuracy metrics (classification)
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
# %matplotlib inline

np.set_printoptions(precision=2)

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalise=False,
                          title=None,
                          cmap=plt.cm.Blues,
                          multi=False):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalise=True`.
    """
    if not title:
        if normalise:
            title = 'Normalised confusion matrix'
        else:
            title = 'Confusion matrix, without normalisation'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Only use the labels that appear in the data
    if multi==True:
    	classes = classes[unique_labels(y_true, y_pred)]
    if normalise:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor");

    fmt = '.2f' if normalise else 'd'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()

    return ax

# predict the test data - change model for whatever name you are using for the model
predicted = knn.predict(X_train[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']])

# Plot non-normalised confusion matrix
plot_confusion_matrix(Y_train, predicted, classes=["0","1","2","3","4","5"])

# Plot normalised confusion matrix
plot_confusion_matrix(Y_train, predicted, classes=["0","1","2","3","4","5"], normalise=True)

# %%
#5.Tuning hyperparameters for accuracy, Optimise hyperparameters

from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier as KNN

# Set the parameters by cross-validation
tuned_parameters = [{'algorithm': ['kd_tree'],
                     'n_neighbors': [ 5, 6, 7 ,8, 9],
                     'weights': ['uniform', 'distance'],
                     'leaf_size': [10,20,30,40,50],
                     'metric': ['minkowski']}]
 
scores = ['accuracy', 'f1_macro']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print("\n")
    clf = GridSearchCV(KNN(), tuned_parameters, cv=5,
                       scoring= score)
    clf.fit(X_train, Y_train)
    print("Best parameters set found on the training set:")
    print(clf.best_params_)
    print("\n")
# Out:
# # Tuning hyperparameters for accuracy
#
#
# Best parameters set found on the training set:
# {'algorithm': 'kd_tree', 'leaf_size': 10, 'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
#
#
# # Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'algorithm': 'kd_tree', 'leaf_size': 10, 'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}

# %%
#6.Check the accuracy metrics again
#7.Predict the test data

predicted = knn.predict(X_test[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']])

# generate a mean accuracy score for the predicted data
test_score = knn.score(X_test[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']], Y_test)

# print the mean accuracy of testing predictions
print("Accuracy score = " + str(round(test_score, 4)))
# Out:
# Accuracy score = 0.263

# %%
#Confusion matrix; Check the accuracy metrics (classification)

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
# %matplotlib inline

np.set_printoptions(precision=2)

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalise=False,
                          title=None,
                          cmap=plt.cm.Blues,
                          multi=False):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalise=True`.
    """
    if not title:
        if normalise:
            title = 'Normalised confusion matrix'
        else:
            title = 'Confusion matrix, without normalisation'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Only use the labels that appear in the data
    if multi==True:
    	classes = classes[unique_labels(y_true, y_pred)]
    if normalise:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor");

    fmt = '.2f' if normalise else 'd'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()

    return ax

# predict the test data - change model for whatever name you are using for the model
predicted = knn.predict(X_test[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']])

# Plot non-normalised confusion matrix
plot_confusion_matrix(Y_test, predicted, classes=["0","1","2","3","4","5"])

# Plot normalised confusion matrix
plot_confusion_matrix(Y_test, predicted, classes=["0","1","2","3","4","5"], normalise=True)

# %%
#calculate f1 score
from sklearn.metrics import f1_score, precision_score, recall_score
macro_prediction=knn.predict(X_test[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']])
f1_score=f1_score(Y_test, macro_prediction, average='macro')
print(f1_score)
# Out:
# 0.16975159363546244

# %%
#Generate prediction results on the whole dataset 
predicted = knn.predict(df[['Duration','touch1','touch2','touch3','touch4','touch5','touch6','DEVICE_TYPE','Journey Length','total_interaction']])
df['predicted_cluster']=predicted

# %%
#evaluate prediction results when compare with original result
def Check(df):

    if df['predicted_cluster']==df['cluster']:
        return "1"
    
    else:
        return "0"

df['knn_p']=df.apply(Check, axis=1)

# %%
#output results
df.to_excel('KNN_Predicted.xlsx')

# %%
df.head()
# Out:
#    UserID  PurchaseID  Duration  touch1    touch2    touch3  touch4    touch5  \
# 0       1           3  0.000217     0.0  0.000000  1.000000     0.0  0.000000
# 1       1           4  0.001666     1.0  0.000000  0.000000     0.0  0.000000
# 2       1           5  0.000556     0.0  0.000000  0.504263     0.0  0.159007
# 3       2           6  0.001505     0.0  0.866747  0.000000     0.0  0.000000
# 4       2           7  0.000043     0.0  0.000000  0.000000     0.0  0.000000
#
#      touch6  DEVICE_TYPE  Journey Length  total_interaction  cluster  \
# 0  0.000000          1.0        0.000000           0.000000        1
# 1  0.000000          1.0        0.392097           0.000588        1
# 2  0.336731          1.0        0.196049           0.000294        1
# 3  0.133253          0.0        0.284195           0.003824        3
# 4  1.000000          0.0        0.000000           0.000147        3
#
#    predicted_cluster knn_p
# 0                  0     0
# 1                  0     0
# 2                  0     0
# 3                  1     0
# 4                  0     0
